# %% [markdown]
# # 1. Introduction to Pandas
#
# ## Overview of Pandas
# Pandas is a powerful open-source data analysis and manipulation library built on top of Python. It provides flexible data structures and functions that make it easy to work with structured data such as tables, time series, and matrices. It's widely used for data cleaning, data transformation, and exploratory data analysis.
#
# ## Key features of Pandas include:
# - Easy handling of missing data.
# - Flexible reshaping and pivoting of datasets.
# - Fast data aggregation and group operations.
# - Seamless integration with other libraries like NumPy, Matplotlib, and SciPy.
#
# ## Installation
# You can install Pandas using pip, which is the Python package manager.
# ```bash
# pip install pandas
# ```
#
# Once installed, you can import the library as follows:

# %%
import pandas as pd

# %% [markdown]
# ## Understanding Core Data Structures
#
# ### 1. Series
# A Pandas **Series** is a one-dimensional labeled array capable of holding any data type (integers, strings, floats, Python objects, etc.). It is similar to a list or array in Python but comes with powerful functionality for data analysis.
#
# #### Example:

# %%
data = [1, 2, 3, 4]
pd.Series(data)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# Each value in the Series has a corresponding index, which defaults to an integer index starting from 0.

# %% [markdown]
# ### 2. **DataFrame**
# A **DataFrame** is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns). It's the most commonly used structure in Pandas.
#
# #### Example:

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}

pd.DataFrame(data)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %% [markdown]
# DataFrames allow for easy manipulation of data in rows and columns, such as filtering, aggregation, and statistical analysis.

# %% [markdown]
# # 2. Data Structures
#
# Pandas provides two key data structures: **Series** and **DataFrame**. These are the building blocks for data manipulation and analysis in Pandas.
#
# ## 1. Series: 1D Array-Like Structure
# A **Series** is a one-dimensional array-like object that can hold any type of data (integers, floats, strings, Python objects, etc.). Each element in the Series has a label, called the **index**.
#
# ### Creating a Series
# You can create a Series from a list, dictionary, or scalar value.

# %%
data = [10, 20, 30, 40]
series = pd.Series(data)
series
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# You can also specify custom index labels:

# %%
series_with_index = pd.Series(data, index=['a', 'b', 'c', 'd'])
series_with_index
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %% [markdown]
# ### Accessing Elements by Index
# Elements in a Series can be accessed using their index.

# %%
print(series[0])  # Outputs: 10
print(series_with_index['b'])  # Outputs: 20
# Out:
# 10
# 20

# %% [markdown]
# You can also use slicing to access a range of elements:

# %%
series[1:3]
# Out:
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
# ## 2. DataFrame: 2D Table-Like Structure
# A DataFrame is a two-dimensional, tabular data structure with labeled rows and columns, similar to a spreadsheet or SQL table. It can contain data of different types (numeric, string, boolean, etc.) in each column.
#
# ### Creating a DataFrame
# You can create a DataFrame from various data sources like lists, dictionaries, CSV, or Excel files.
#
# **From a Dictionary:**

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %% [markdown]
# #### From a List of Lists:

# %%
data = [
    ['Alice', 25, 'New York'],
    ['Bob', 30, 'Los Angeles'],
    ['Charlie', 35, 'Chicago']
]

df = pd.DataFrame(data, columns=['Name', 'Age', 'City'])
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %% [markdown]
# #### From a CSV File:

# %%
df = pd.read_csv('data/users.csv')
df
# Out:
#               name            phone                              email  \
# 0        Carl Todd        0800 1111  mauris.suspendisse@protonmail.net
# 1    Imani Hartman    070 6524 1233                 tempor@hotmail.edu
# 2      Lynn Carver    0980 367 7825        convallis.erat.eget@aol.org
# 3    Sade Martinez       0845 46 43               dui.cum@hotmail.couk
# 4     Uriel Romero     07381 542211             elit.nulla@outlook.com
# ..             ...              ...                                ...
# 95   Hermione Carr      0800 272602         non.dapibus@protonmail.com
# 96    Darrel Gates  (024) 0676 6116            orci.phasellus@yahoo.ca
# 97  Marshall Sykes      0800 728475         sapien.cras@protonmail.org
# 98    Hyatt Ashley    0873 882 4844                imperdiet@yahoo.org
# 99   Palmer Bowers    076 9264 4467                      risus@aol.com
#
#                              address    postalZip        region  \
# 0            Ap #556-6076 Lorem, Av.        18838  Azad Kashmir
# 1                893-9946 Sociis Rd.       575444      Victoria
# 2                  9010 Auctor. Road        25252   East Region
# 3                560-9011 Magna. St.       491187        Manisa
# 4                  596-1288 Amet Rd.         6700   Nova Scotia
# ..                               ...          ...           ...
# 95                721-3192 Magna Rd.        26930    Queensland
# 96       P.O. Box 976, 7887 Diam St.         4144    West Papua
# 97                 1495 Egestas. Rd.        18102       Utrecht
# 98  P.O. Box 490, 4963 Mauris Avenue        16882     Trøndelag
# 99              Ap #698-4249 Sed St.  30966-60458         Delta
#
#            country  list                                               text  \
# 0          Ireland     1  pede ac urna. Ut tincidunt vehicula risus. Nul...
# 1            India    19  eget odio. Aliquam vulputate ullamcorper magna...
# 2         Pakistan    17  senectus et netus et malesuada fames ac turpis...
# 3         Pakistan     1  dui augue eu tellus. Phasellus elit pede, male...
# 4        Singapore    11  vestibulum massa rutrum magna. Cras convallis ...
# ..             ...   ...                                                ...
# 95        Pakistan    19  orci, adipiscing non, luctus sit amet, faucibu...
# 96  United Kingdom     1  amet ultricies sem magna nec quam. Curabitur v...
# 97           India     1  mi lacinia mattis. Integer eu lacus. Quisque i...
# 98         Vietnam     7  vestibulum. Mauris magna. Duis dignissim tempo...
# 99          Norway    11  nec orci. Donec nibh. Quisque nonummy ipsum no...
#
#     numberrange currency alphanumeric
# 0             2    $3.61  NGM77DMT8HR
# 1             1   $40.74  ROO25QJR7EJ
# 2             1   $84.87  OAM72YZF3QW
# 3             2   $36.73  HDQ00BJN2QA
# 4             4   $45.69  VTX15TUS7TC
# ..          ...      ...          ...
# 95            3    $6.14  UDS39INL1CX
# 96            7   $79.54  PXO54TUV8NH
# 97            7   $25.30  IUC28LDY7MM
# 98            2   $36.24  HWP81EEB2HK
# 99            8   $89.52  SXH88MTP8RT
#
# [100 rows x 12 columns]

# %% [markdown]
# ### Accessing Rows and Columns
# You can access rows and columns in a DataFrame by using labels or positions.
#
# #### Accessing Columns:

# %%
df['name']
# Out:
# 0          Carl Todd
# 1      Imani Hartman
# 2        Lynn Carver
# 3      Sade Martinez
# 4       Uriel Romero
#            ...
# 95     Hermione Carr
# 96      Darrel Gates
# 97    Marshall Sykes
# 98      Hyatt Ashley
# 99     Palmer Bowers
# Name: name, Length: 100, dtype: object

# %%
df[['name', 'address']]
# Out:
#               name                           address
# 0        Carl Todd           Ap #556-6076 Lorem, Av.
# 1    Imani Hartman               893-9946 Sociis Rd.
# 2      Lynn Carver                 9010 Auctor. Road
# 3    Sade Martinez               560-9011 Magna. St.
# 4     Uriel Romero                 596-1288 Amet Rd.
# ..             ...                               ...
# 95   Hermione Carr                721-3192 Magna Rd.
# 96    Darrel Gates       P.O. Box 976, 7887 Diam St.
# 97  Marshall Sykes                 1495 Egestas. Rd.
# 98    Hyatt Ashley  P.O. Box 490, 4963 Mauris Avenue
# 99   Palmer Bowers              Ap #698-4249 Sed St.
#
# [100 rows x 2 columns]

# %% [markdown]
# #### Accessing Rows:
# You can use `.loc[]` for label-based indexing or `.iloc[]` for position-based indexing.

# %%
df.iloc[1]
# Out:
# name                                                Imani Hartman
# phone                                               070 6524 1233
# email                                          tempor@hotmail.edu
# address                                       893-9946 Sociis Rd.
# postalZip                                                  575444
# region                                                   Victoria
# country                                                     India
# list                                                           19
# text            eget odio. Aliquam vulputate ullamcorper magna...
# numberrange                                                     1
# currency                                                   $40.74
# alphanumeric                                          ROO25QJR7EJ
# Name: 1, dtype: object

# %%
df_with_custom_index = df.set_index('name')
df_with_custom_index
# Out:
#                           phone                              email  \
# name
# Carl Todd             0800 1111  mauris.suspendisse@protonmail.net
# Imani Hartman     070 6524 1233                 tempor@hotmail.edu
# Lynn Carver       0980 367 7825        convallis.erat.eget@aol.org
# Sade Martinez        0845 46 43               dui.cum@hotmail.couk
# Uriel Romero       07381 542211             elit.nulla@outlook.com
# ...                         ...                                ...
# Hermione Carr       0800 272602         non.dapibus@protonmail.com
# Darrel Gates    (024) 0676 6116            orci.phasellus@yahoo.ca
# Marshall Sykes      0800 728475         sapien.cras@protonmail.org
# Hyatt Ashley      0873 882 4844                imperdiet@yahoo.org
# Palmer Bowers     076 9264 4467                      risus@aol.com
#
#                                          address    postalZip        region  \
# name
# Carl Todd                Ap #556-6076 Lorem, Av.        18838  Azad Kashmir
# Imani Hartman                893-9946 Sociis Rd.       575444      Victoria
# Lynn Carver                    9010 Auctor. Road        25252   East Region
# Sade Martinez                560-9011 Magna. St.       491187        Manisa
# Uriel Romero                   596-1288 Amet Rd.         6700   Nova Scotia
# ...                                          ...          ...           ...
# Hermione Carr                 721-3192 Magna Rd.        26930    Queensland
# Darrel Gates         P.O. Box 976, 7887 Diam St.         4144    West Papua
# Marshall Sykes                 1495 Egestas. Rd.        18102       Utrecht
# Hyatt Ashley    P.O. Box 490, 4963 Mauris Avenue        16882     Trøndelag
# Palmer Bowers               Ap #698-4249 Sed St.  30966-60458         Delta
#
#                        country  list  \
# name
# Carl Todd              Ireland     1
# Imani Hartman            India    19
# Lynn Carver           Pakistan    17
# Sade Martinez         Pakistan     1
# Uriel Romero         Singapore    11
# ...                        ...   ...
# Hermione Carr         Pakistan    19
# Darrel Gates    United Kingdom     1
# Marshall Sykes           India     1
# Hyatt Ashley           Vietnam     7
# Palmer Bowers           Norway    11
#
#                                                              text  \
# name
# Carl Todd       pede ac urna. Ut tincidunt vehicula risus. Nul...
# Imani Hartman   eget odio. Aliquam vulputate ullamcorper magna...
# Lynn Carver     senectus et netus et malesuada fames ac turpis...
# Sade Martinez   dui augue eu tellus. Phasellus elit pede, male...
# Uriel Romero    vestibulum massa rutrum magna. Cras convallis ...
# ...                                                           ...
# Hermione Carr   orci, adipiscing non, luctus sit amet, faucibu...
# Darrel Gates    amet ultricies sem magna nec quam. Curabitur v...
# Marshall Sykes  mi lacinia mattis. Integer eu lacus. Quisque i...
# Hyatt Ashley    vestibulum. Mauris magna. Duis dignissim tempo...
# Palmer Bowers   nec orci. Donec nibh. Quisque nonummy ipsum no...
#
#                 numberrange currency alphanumeric
# name
# Carl Todd                 2    $3.61  NGM77DMT8HR
# Imani Hartman             1   $40.74  ROO25QJR7EJ
# Lynn Carver               1   $84.87  OAM72YZF3QW
# Sade Martinez             2   $36.73  HDQ00BJN2QA
# Uriel Romero              4   $45.69  VTX15TUS7TC
# ...                     ...      ...          ...
# Hermione Carr             3    $6.14  UDS39INL1CX
# Darrel Gates              7   $79.54  PXO54TUV8NH
# Marshall Sykes            7   $25.30  IUC28LDY7MM
# Hyatt Ashley              2   $36.24  HWP81EEB2HK
# Palmer Bowers             8   $89.52  SXH88MTP8RT
#
# [100 rows x 11 columns]

# %% [markdown]
# ### Indexing and Selecting Data
# Pandas provides powerful indexing and selection capabilities:
#
# #### Selecting a Single Element:

# %%
df.at[0, 'name']
# Out:
# 'Carl Todd'

# %% [markdown]
# #### Selecting a Range of Rows and Columns:

# %%
df.loc[0:1, 'name':'phone']
# Out:
#             name          phone
# 0      Carl Todd      0800 1111
# 1  Imani Hartman  070 6524 1233

# %% [markdown]
# # 3. Data Manipulation
#
# Pandas offers powerful tools for reading, writing, and manipulating structured data. This section will cover essential operations for data manipulation, including reading and writing data, inspecting data, selecting specific rows and columns, filtering, and handling missing values.
#
# ---
#
# ## 1. Reading and Writing Data
#
# ### Reading Data
# Pandas can read data from various file formats, including CSV, Excel, JSON, and SQL databases.
#
# #### Reading from a CSV file:

# %%
df = pd.read_csv('data/users.csv')
df.head()  # Displays the first few rows
# Out:
#             name          phone                              email  \
# 0      Carl Todd      0800 1111  mauris.suspendisse@protonmail.net
# 1  Imani Hartman  070 6524 1233                 tempor@hotmail.edu
# 2    Lynn Carver  0980 367 7825        convallis.erat.eget@aol.org
# 3  Sade Martinez     0845 46 43               dui.cum@hotmail.couk
# 4   Uriel Romero   07381 542211             elit.nulla@outlook.com
#
#                    address postalZip        region    country  list  \
# 0  Ap #556-6076 Lorem, Av.     18838  Azad Kashmir    Ireland     1
# 1      893-9946 Sociis Rd.    575444      Victoria      India    19
# 2        9010 Auctor. Road     25252   East Region   Pakistan    17
# 3      560-9011 Magna. St.    491187        Manisa   Pakistan     1
# 4        596-1288 Amet Rd.      6700   Nova Scotia  Singapore    11
#
#                                                 text  numberrange currency  \
# 0  pede ac urna. Ut tincidunt vehicula risus. Nul...            2    $3.61
# 1  eget odio. Aliquam vulputate ullamcorper magna...            1   $40.74
# 2  senectus et netus et malesuada fames ac turpis...            1   $84.87
# 3  dui augue eu tellus. Phasellus elit pede, male...            2   $36.73
# 4  vestibulum massa rutrum magna. Cras convallis ...            4   $45.69
#
#   alphanumeric
# 0  NGM77DMT8HR
# 1  ROO25QJR7EJ
# 2  OAM72YZF3QW
# 3  HDQ00BJN2QA
# 4  VTX15TUS7TC

# %% [markdown]
# #### Reading from an Excel file:

# %%
df = pd.read_excel('data/users.xlsx')
df.head()
# Out:
#             name          phone                              email  \
# 0      Carl Todd      0800 1111  mauris.suspendisse@protonmail.net
# 1  Imani Hartman  070 6524 1233                 tempor@hotmail.edu
# 2    Lynn Carver  0980 367 7825        convallis.erat.eget@aol.org
# 3  Sade Martinez     0845 46 43               dui.cum@hotmail.couk
# 4   Uriel Romero   07381 542211             elit.nulla@outlook.com
#
#                    address postalZip        region    country  list  \
# 0  Ap #556-6076 Lorem, Av.     18838  Azad Kashmir    Ireland     1
# 1      893-9946 Sociis Rd.    575444      Victoria      India    19
# 2        9010 Auctor. Road     25252   East Region   Pakistan    17
# 3      560-9011 Magna. St.    491187        Manisa   Pakistan     1
# 4        596-1288 Amet Rd.      6700   Nova Scotia  Singapore    11
#
#                                                 text  numberrange currency  \
# 0  pede ac urna. Ut tincidunt vehicula risus. Nul...            2    $3.61
# 1  eget odio. Aliquam vulputate ullamcorper magna...            1   $40.74
# 2  senectus et netus et malesuada fames ac turpis...            1   $84.87
# 3  dui augue eu tellus. Phasellus elit pede, male...            2   $36.73
# 4  vestibulum massa rutrum magna. Cras convallis ...            4   $45.69
#
#   alphanumeric
# 0  NGM77DMT8HR
# 1  ROO25QJR7EJ
# 2  OAM72YZF3QW
# 3  HDQ00BJN2QA
# 4  VTX15TUS7TC

# %% [markdown]
# #### Reading from a JSON file:

# %%
df = pd.read_json('data/users.json')
df.head()
# Out:
#             name          phone                              email  \
# 0      Carl Todd      0800 1111  mauris.suspendisse@protonmail.net
# 1  Imani Hartman  070 6524 1233                 tempor@hotmail.edu
# 2    Lynn Carver  0980 367 7825        convallis.erat.eget@aol.org
# 3  Sade Martinez     0845 46 43               dui.cum@hotmail.couk
# 4   Uriel Romero   07381 542211             elit.nulla@outlook.com
#
#                    address postalZip        region    country  list  \
# 0  Ap #556-6076 Lorem, Av.     18838  Azad Kashmir    Ireland     1
# 1      893-9946 Sociis Rd.    575444      Victoria      India    19
# 2        9010 Auctor. Road     25252   East Region   Pakistan    17
# 3      560-9011 Magna. St.    491187        Manisa   Pakistan     1
# 4        596-1288 Amet Rd.      6700   Nova Scotia  Singapore    11
#
#                                                 text  numberrange currency  \
# 0  pede ac urna. Ut tincidunt vehicula risus. Nul...            2    $3.61
# 1  eget odio. Aliquam vulputate ullamcorper magna...            1   $40.74
# 2  senectus et netus et malesuada fames ac turpis...            1   $84.87
# 3  dui augue eu tellus. Phasellus elit pede, male...            2   $36.73
# 4  vestibulum massa rutrum magna. Cras convallis ...            4   $45.69
#
#   alphanumeric
# 0  NGM77DMT8HR
# 1  ROO25QJR7EJ
# 2  OAM72YZF3QW
# 3  HDQ00BJN2QA
# 4  VTX15TUS7TC

# %% [markdown]
# #### Reading from SQL:

# %%
# import sqlite3

# conn = sqlite3.connect('data/users.sql')
# df = pd.read_sql('SELECT * FROM table_name', conn)
# print(df.head())

# %% [markdown]
# ### Writing Data
# You can write a Pandas DataFrame to various formats like CSV, Excel, etc.
#
# #### Writing to a CSV file:

# %%
df.to_csv('data/output.csv', index=False)  # Write DataFrame to a CSV file

# %% [markdown]
# #### Writing to an Excel file:

# %%
df.to_excel('data/output.xlsx', index=False)

# %% [markdown]
# ## 2. Viewing and Inspecting Data
# ### Viewing Data
# Pandas provides easy ways to view and inspect your data.
#
# #### Viewing the First/Last Rows:
# `head()`: Displays the first few rows.
# `tail()`: Displays the last few rows.

# %%
print(df.head())  # First 5 rows by default
print(df.tail(3))  # Last 3 rows
# Out:
#             name          phone                              email  \
# 0      Carl Todd      0800 1111  mauris.suspendisse@protonmail.net
# 1  Imani Hartman  070 6524 1233                 tempor@hotmail.edu
# 2    Lynn Carver  0980 367 7825        convallis.erat.eget@aol.org
# 3  Sade Martinez     0845 46 43               dui.cum@hotmail.couk
# 4   Uriel Romero   07381 542211             elit.nulla@outlook.com
#
#                    address postalZip        region    country  list  \
# 0  Ap #556-6076 Lorem, Av.     18838  Azad Kashmir    Ireland     1
# 1      893-9946 Sociis Rd.    575444      Victoria      India    19
# 2        9010 Auctor. Road     25252   East Region   Pakistan    17
# 3      560-9011 Magna. St.    491187        Manisa   Pakistan     1
# 4        596-1288 Amet Rd.      6700   Nova Scotia  Singapore    11
#
#                                                 text  numberrange currency  \
# 0  pede ac urna. Ut tincidunt vehicula risus. Nul...            2    $3.61
# 1  eget odio. Aliquam vulputate ullamcorper magna...            1   $40.74
# 2  senectus et netus et malesuada fames ac turpis...            1   $84.87
# 3  dui augue eu tellus. Phasellus elit pede, male...            2   $36.73
# 4  vestibulum massa rutrum magna. Cras convallis ...            4   $45.69
#
#   alphanumeric
# 0  NGM77DMT8HR
# 1  ROO25QJR7EJ
# 2  OAM72YZF3QW
# 3  HDQ00BJN2QA
# 4  VTX15TUS7TC
#               name          phone                       email  \
# 97  Marshall Sykes    0800 728475  sapien.cras@protonmail.org
# 98    Hyatt Ashley  0873 882 4844         imperdiet@yahoo.org
# 99   Palmer Bowers  076 9264 4467               risus@aol.com
#
#                              address    postalZip     region  country  list  \
# 97                 1495 Egestas. Rd.        18102    Utrecht    India     1
# 98  P.O. Box 490, 4963 Mauris Avenue        16882  Trøndelag  Vietnam     7
# 99              Ap #698-4249 Sed St.  30966-60458      Delta   Norway    11
#
#                                                  text  numberrange currency  \
# 97  mi lacinia mattis. Integer eu lacus. Quisque i...            7   $25.30
# 98  vestibulum. Mauris magna. Duis dignissim tempo...            2   $36.24
# 99  nec orci. Donec nibh. Quisque nonummy ipsum no...            8   $89.52
#
#    alphanumeric
# 97  IUC28LDY7MM
# 98  HWP81EEB2HK
# 99  SXH88MTP8RT

# %% [markdown]
# ### Inspecting Data
# You can inspect the structure and summary of your data using the following methods:
#
# - `info()`: Shows summary information about the DataFrame, such as the number of rows, column data types, and memory usage.
# - `describe()`: Provides descriptive statistics for numeric columns.

# %%
print(df.info())  # Get an overview of the DataFrame
print(df.describe())  # Statistical summary for numeric columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          100 non-null    object
#  1   phone         100 non-null    object
#  2   email         100 non-null    object
#  3   address       100 non-null    object
#  4   postalZip     100 non-null    object
#  5   region        100 non-null    object
#  6   country       100 non-null    object
#  7   list          100 non-null    int64
#  8   text          100 non-null    object
#  9   numberrange   100 non-null    int64
#  10  currency      100 non-null    object
#  11  alphanumeric  100 non-null    object
# dtypes: int64(2), object(10)
# memory usage: 9.5+ KB
# None
#              list  numberrange
# count  100.000000   100.000000
# mean    10.260000     4.850000
# std      6.290316     2.731688
# min      1.000000     0.000000
# 25%      5.000000     2.000000
# 50%     11.000000     5.000000
# 75%     15.000000     7.000000
# max     19.000000    10.000000

# %% [markdown]
# ## 3. Data Selection
# ### Selecting Rows and Columns
# You can select specific rows and columns in a DataFrame using labels or index positions.
#
# #### Selecting Columns:

# %%
df['phone'] # Selecting a single column
# Out:
# 0           0800 1111
# 1       070 6524 1233
# 2       0980 367 7825
# 3          0845 46 43
# 4        07381 542211
#            ...
# 95        0800 272602
# 96    (024) 0676 6116
# 97        0800 728475
# 98      0873 882 4844
# 99      076 9264 4467
# Name: phone, Length: 100, dtype: object

# %%
df[['phone', 'name']] # Selecting multiple columns
# Out:
#               phone            name
# 0         0800 1111       Carl Todd
# 1     070 6524 1233   Imani Hartman
# 2     0980 367 7825     Lynn Carver
# 3        0845 46 43   Sade Martinez
# 4      07381 542211    Uriel Romero
# ..              ...             ...
# 95      0800 272602   Hermione Carr
# 96  (024) 0676 6116    Darrel Gates
# 97      0800 728475  Marshall Sykes
# 98    0873 882 4844    Hyatt Ashley
# 99    076 9264 4467   Palmer Bowers
#
# [100 rows x 2 columns]

# %% [markdown]
# #### Selecting Rows:
# You can select rows using label-based indexing (loc[]) or integer position-based indexing (iloc[]).
#
# - `loc[]`: Selects data by row labels and column names.
# - `iloc[]`: Selects data by index position.

# %%
df.loc[0] # Select a single row by label
# Out:
# name                                                    Carl Todd
# phone                                                   0800 1111
# email                           mauris.suspendisse@protonmail.net
# address                                   Ap #556-6076 Lorem, Av.
# postalZip                                                   18838
# region                                               Azad Kashmir
# country                                                   Ireland
# list                                                            1
# text            pede ac urna. Ut tincidunt vehicula risus. Nul...
# numberrange                                                     2
# currency                                                    $3.61
# alphanumeric                                          NGM77DMT8HR
# Name: 0, dtype: object

# %%
df.iloc[0] # Select a single row by index position
# Out:
# name                                                    Carl Todd
# phone                                                   0800 1111
# email                           mauris.suspendisse@protonmail.net
# address                                   Ap #556-6076 Lorem, Av.
# postalZip                                                   18838
# region                                               Azad Kashmir
# country                                                   Ireland
# list                                                            1
# text            pede ac urna. Ut tincidunt vehicula risus. Nul...
# numberrange                                                     2
# currency                                                    $3.61
# alphanumeric                                          NGM77DMT8HR
# Name: 0, dtype: object

# %% [markdown]
# ### Slicing and Indexing
# You can slice rows and columns from a DataFrame using loc[] and iloc[].
#
# Example:

# %%
df.loc[0:2, 'name':'phone'] # Select specific rows and columns using loc
# Out:
#             name          phone
# 0      Carl Todd      0800 1111
# 1  Imani Hartman  070 6524 1233
# 2    Lynn Carver  0980 367 7825

# %%
df.iloc[0:2, [0, 2]] # Select rows by index and specific columns using iloc
# Out:
#             name                              email
# 0      Carl Todd  mauris.suspendisse@protonmail.net
# 1  Imani Hartman                 tempor@hotmail.edu

# %% [markdown]
# ## 4. Filtering Data
# ### Conditional Filtering
# You can filter data by applying conditions to the DataFrame.
#
# **Example:**

# %%
df[df['numberrange'] < 1] # Filter rows where a column's value is greater than a threshold
# Out:
#                  name          phone                     email  \
# 34  Lawrence Callahan    0800 443215      diam.nunc@yahoo.couk
# 56       Lucian Poole  0381 848 2226  cubilia.curae@google.net
#
#                        address postalZip   region        country  list  \
# 34            310-365 Nec, Av.   6258 RJ  Limburg  United States     7
# 56  Ap #208-8133 Convallis St.    854031   Centre    Philippines    17
#
#                                                  text  numberrange currency  \
# 34  odio semper cursus. Integer mollis. Integer ti...            0   $50.25
# 56  velit eu sem. Pellentesque ut ipsum ac mi elei...            0   $14.90
#
#    alphanumeric
# 34  JFH94FMU5JM
# 56  KUX22WPY5HF

# %% [markdown]
# ### Boolean Indexing
# You can apply conditions directly using Boolean indexing.

# %%
df[(df['numberrange'] < 20) & (df['country'] == 'Ireland')] # Using boolean conditions to filter rows
# Out:
#                name            phone                              email  \
# 0         Carl Todd        0800 1111  mauris.suspendisse@protonmail.net
# 12  Donovan Tillman      0800 273521             egestas.ligula@aol.edu
# 76      Uriah Brock     07624 982244                 mauris.eu@aol.couk
# 83    James Simpson  (0117) 280 6451               metus.in@outlook.com
#
#                     address postalZip             region  country  list  \
# 0   Ap #556-6076 Lorem, Av.     18838       Azad Kashmir  Ireland     1
# 12              9284 Ut St.    155171  Arunachal Pradesh  Ireland    15
# 76       863-6171 Id Street    11-804             Umbria  Ireland    13
# 83  Ap #480-5104 Primis Ave     95616       Minas Gerais  Ireland    11
#
#                                                  text  numberrange currency  \
# 0   pede ac urna. Ut tincidunt vehicula risus. Nul...            2    $3.61
# 12  amet orci. Ut sagittis lobortis mauris. Suspen...            1   $54.16
# 76  mauris id sapien. Cras dolor dolor, tempus non...            7   $91.65
# 83  nibh vulputate mauris sagittis placerat. Cras ...            1   $35.21
#
#    alphanumeric
# 0   NGM77DMT8HR
# 12  ORE63FCY7PW
# 76  ULS13XYB5QL
# 83  MMU46BNE3CS

# %% [markdown]
# ## 5. Adding/Removing Columns
# ### Adding New Columns
# You can add new columns to a DataFrame using assignment.
#
# #### Example:

# %%
df['name_and_phone'] = df['name'] + df['phone']
df
# Out:
#               name            phone                              email  \
# 0        Carl Todd        0800 1111  mauris.suspendisse@protonmail.net
# 1    Imani Hartman    070 6524 1233                 tempor@hotmail.edu
# 2      Lynn Carver    0980 367 7825        convallis.erat.eget@aol.org
# 3    Sade Martinez       0845 46 43               dui.cum@hotmail.couk
# 4     Uriel Romero     07381 542211             elit.nulla@outlook.com
# ..             ...              ...                                ...
# 95   Hermione Carr      0800 272602         non.dapibus@protonmail.com
# 96    Darrel Gates  (024) 0676 6116            orci.phasellus@yahoo.ca
# 97  Marshall Sykes      0800 728475         sapien.cras@protonmail.org
# 98    Hyatt Ashley    0873 882 4844                imperdiet@yahoo.org
# 99   Palmer Bowers    076 9264 4467                      risus@aol.com
#
#                              address    postalZip        region  \
# 0            Ap #556-6076 Lorem, Av.        18838  Azad Kashmir
# 1                893-9946 Sociis Rd.       575444      Victoria
# 2                  9010 Auctor. Road        25252   East Region
# 3                560-9011 Magna. St.       491187        Manisa
# 4                  596-1288 Amet Rd.         6700   Nova Scotia
# ..                               ...          ...           ...
# 95                721-3192 Magna Rd.        26930    Queensland
# 96       P.O. Box 976, 7887 Diam St.         4144    West Papua
# 97                 1495 Egestas. Rd.        18102       Utrecht
# 98  P.O. Box 490, 4963 Mauris Avenue        16882     Trøndelag
# 99              Ap #698-4249 Sed St.  30966-60458         Delta
#
#            country  list                                               text  \
# 0          Ireland     1  pede ac urna. Ut tincidunt vehicula risus. Nul...
# 1            India    19  eget odio. Aliquam vulputate ullamcorper magna...
# 2         Pakistan    17  senectus et netus et malesuada fames ac turpis...
# 3         Pakistan     1  dui augue eu tellus. Phasellus elit pede, male...
# 4        Singapore    11  vestibulum massa rutrum magna. Cras convallis ...
# ..             ...   ...                                                ...
# 95        Pakistan    19  orci, adipiscing non, luctus sit amet, faucibu...
# 96  United Kingdom     1  amet ultricies sem magna nec quam. Curabitur v...
# 97           India     1  mi lacinia mattis. Integer eu lacus. Quisque i...
# 98         Vietnam     7  vestibulum. Mauris magna. Duis dignissim tempo...
# 99          Norway    11  nec orci. Donec nibh. Quisque nonummy ipsum no...
#
#     numberrange currency alphanumeric               name_and_phone
# 0             2    $3.61  NGM77DMT8HR           Carl Todd0800 1111
# 1             1   $40.74  ROO25QJR7EJ   Imani Hartman070 6524 1233
# 2             1   $84.87  OAM72YZF3QW     Lynn Carver0980 367 7825
# 3             2   $36.73  HDQ00BJN2QA      Sade Martinez0845 46 43
# 4             4   $45.69  VTX15TUS7TC     Uriel Romero07381 542211
# ..          ...      ...          ...                          ...
# 95            3    $6.14  UDS39INL1CX     Hermione Carr0800 272602
# 96            7   $79.54  PXO54TUV8NH  Darrel Gates(024) 0676 6116
# 97            7   $25.30  IUC28LDY7MM    Marshall Sykes0800 728475
# 98            2   $36.24  HWP81EEB2HK    Hyatt Ashley0873 882 4844
# 99            8   $89.52  SXH88MTP8RT   Palmer Bowers076 9264 4467
#
# [100 rows x 13 columns]

# %% [markdown]
# ### Removing Columns
# You can remove columns using the drop() method.
#
# #### Example:

# %%
# Drop a single column
df.drop('name_and_phone', axis=1)
# Out:
#               name            phone                              email  \
# 0        Carl Todd        0800 1111  mauris.suspendisse@protonmail.net
# 1    Imani Hartman    070 6524 1233                 tempor@hotmail.edu
# 2      Lynn Carver    0980 367 7825        convallis.erat.eget@aol.org
# 3    Sade Martinez       0845 46 43               dui.cum@hotmail.couk
# 4     Uriel Romero     07381 542211             elit.nulla@outlook.com
# ..             ...              ...                                ...
# 95   Hermione Carr      0800 272602         non.dapibus@protonmail.com
# 96    Darrel Gates  (024) 0676 6116            orci.phasellus@yahoo.ca
# 97  Marshall Sykes      0800 728475         sapien.cras@protonmail.org
# 98    Hyatt Ashley    0873 882 4844                imperdiet@yahoo.org
# 99   Palmer Bowers    076 9264 4467                      risus@aol.com
#
#                              address    postalZip        region  \
# 0            Ap #556-6076 Lorem, Av.        18838  Azad Kashmir
# 1                893-9946 Sociis Rd.       575444      Victoria
# 2                  9010 Auctor. Road        25252   East Region
# 3                560-9011 Magna. St.       491187        Manisa
# 4                  596-1288 Amet Rd.         6700   Nova Scotia
# ..                               ...          ...           ...
# 95                721-3192 Magna Rd.        26930    Queensland
# 96       P.O. Box 976, 7887 Diam St.         4144    West Papua
# 97                 1495 Egestas. Rd.        18102       Utrecht
# 98  P.O. Box 490, 4963 Mauris Avenue        16882     Trøndelag
# 99              Ap #698-4249 Sed St.  30966-60458         Delta
#
#            country  list                                               text  \
# 0          Ireland     1  pede ac urna. Ut tincidunt vehicula risus. Nul...
# 1            India    19  eget odio. Aliquam vulputate ullamcorper magna...
# 2         Pakistan    17  senectus et netus et malesuada fames ac turpis...
# 3         Pakistan     1  dui augue eu tellus. Phasellus elit pede, male...
# 4        Singapore    11  vestibulum massa rutrum magna. Cras convallis ...
# ..             ...   ...                                                ...
# 95        Pakistan    19  orci, adipiscing non, luctus sit amet, faucibu...
# 96  United Kingdom     1  amet ultricies sem magna nec quam. Curabitur v...
# 97           India     1  mi lacinia mattis. Integer eu lacus. Quisque i...
# 98         Vietnam     7  vestibulum. Mauris magna. Duis dignissim tempo...
# 99          Norway    11  nec orci. Donec nibh. Quisque nonummy ipsum no...
#
#     numberrange currency alphanumeric
# 0             2    $3.61  NGM77DMT8HR
# 1             1   $40.74  ROO25QJR7EJ
# 2             1   $84.87  OAM72YZF3QW
# 3             2   $36.73  HDQ00BJN2QA
# 4             4   $45.69  VTX15TUS7TC
# ..          ...      ...          ...
# 95            3    $6.14  UDS39INL1CX
# 96            7   $79.54  PXO54TUV8NH
# 97            7   $25.30  IUC28LDY7MM
# 98            2   $36.24  HWP81EEB2HK
# 99            8   $89.52  SXH88MTP8RT
#
# [100 rows x 12 columns]

# %%
# Drop multiple columns
df.drop(['name', 'phone'], axis=1)
# Out:
#                                 email                           address  \
# 0   mauris.suspendisse@protonmail.net           Ap #556-6076 Lorem, Av.
# 1                  tempor@hotmail.edu               893-9946 Sociis Rd.
# 2         convallis.erat.eget@aol.org                 9010 Auctor. Road
# 3                dui.cum@hotmail.couk               560-9011 Magna. St.
# 4              elit.nulla@outlook.com                 596-1288 Amet Rd.
# ..                                ...                               ...
# 95         non.dapibus@protonmail.com                721-3192 Magna Rd.
# 96            orci.phasellus@yahoo.ca       P.O. Box 976, 7887 Diam St.
# 97         sapien.cras@protonmail.org                 1495 Egestas. Rd.
# 98                imperdiet@yahoo.org  P.O. Box 490, 4963 Mauris Avenue
# 99                      risus@aol.com              Ap #698-4249 Sed St.
#
#       postalZip        region         country  list  \
# 0         18838  Azad Kashmir         Ireland     1
# 1        575444      Victoria           India    19
# 2         25252   East Region        Pakistan    17
# 3        491187        Manisa        Pakistan     1
# 4          6700   Nova Scotia       Singapore    11
# ..          ...           ...             ...   ...
# 95        26930    Queensland        Pakistan    19
# 96         4144    West Papua  United Kingdom     1
# 97        18102       Utrecht           India     1
# 98        16882     Trøndelag         Vietnam     7
# 99  30966-60458         Delta          Norway    11
#
#                                                  text  numberrange currency  \
# 0   pede ac urna. Ut tincidunt vehicula risus. Nul...            2    $3.61
# 1   eget odio. Aliquam vulputate ullamcorper magna...            1   $40.74
# 2   senectus et netus et malesuada fames ac turpis...            1   $84.87
# 3   dui augue eu tellus. Phasellus elit pede, male...            2   $36.73
# 4   vestibulum massa rutrum magna. Cras convallis ...            4   $45.69
# ..                                                ...          ...      ...
# 95  orci, adipiscing non, luctus sit amet, faucibu...            3    $6.14
# 96  amet ultricies sem magna nec quam. Curabitur v...            7   $79.54
# 97  mi lacinia mattis. Integer eu lacus. Quisque i...            7   $25.30
# 98  vestibulum. Mauris magna. Duis dignissim tempo...            2   $36.24
# 99  nec orci. Donec nibh. Quisque nonummy ipsum no...            8   $89.52
#
#    alphanumeric               name_and_phone
# 0   NGM77DMT8HR           Carl Todd0800 1111
# 1   ROO25QJR7EJ   Imani Hartman070 6524 1233
# 2   OAM72YZF3QW     Lynn Carver0980 367 7825
# 3   HDQ00BJN2QA      Sade Martinez0845 46 43
# 4   VTX15TUS7TC     Uriel Romero07381 542211
# ..          ...                          ...
# 95  UDS39INL1CX     Hermione Carr0800 272602
# 96  PXO54TUV8NH  Darrel Gates(024) 0676 6116
# 97  IUC28LDY7MM    Marshall Sykes0800 728475
# 98  HWP81EEB2HK    Hyatt Ashley0873 882 4844
# 99  SXH88MTP8RT   Palmer Bowers076 9264 4467
#
# [100 rows x 11 columns]

# %% [markdown]
# ## 6. Handling Missing Data
# Missing data is common in real-world datasets. Pandas provides several functions to detect and handle missing values.
#
# ### Detecting Missing Data
# - `isnull()`: Detects missing values (NaN).
# - `notnull()`: Detects non-missing values

# %%
df.isnull()  # Returns True for NaN values
# Out:
#      name  phone  email  address  postalZip  region  country   list   text  \
# 0   False  False  False    False      False   False    False  False  False
# 1   False  False  False    False      False   False    False  False  False
# 2   False  False  False    False      False   False    False  False  False
# 3   False  False  False    False      False   False    False  False  False
# 4   False  False  False    False      False   False    False  False  False
# ..    ...    ...    ...      ...        ...     ...      ...    ...    ...
# 95  False  False  False    False      False   False    False  False  False
# 96  False  False  False    False      False   False    False  False  False
# 97  False  False  False    False      False   False    False  False  False
# 98  False  False  False    False      False   False    False  False  False
# 99  False  False  False    False      False   False    False  False  False
#
#     numberrange  currency  alphanumeric  name_and_phone
# 0         False     False         False           False
# 1         False     False         False           False
# 2         False     False         False           False
# 3         False     False         False           False
# 4         False     False         False           False
# ..          ...       ...           ...             ...
# 95        False     False         False           False
# 96        False     False         False           False
# 97        False     False         False           False
# 98        False     False         False           False
# 99        False     False         False           False
#
# [100 rows x 13 columns]

# %% [markdown]
# ### Dropping Missing Data
# You can drop rows or columns that contain missing values using dropna().
#
# #### Example:

# %%
# Drop rows with any missing values
df.dropna()
# Out:
#               name            phone                              email  \
# 0        Carl Todd        0800 1111  mauris.suspendisse@protonmail.net
# 1    Imani Hartman    070 6524 1233                 tempor@hotmail.edu
# 2      Lynn Carver    0980 367 7825        convallis.erat.eget@aol.org
# 3    Sade Martinez       0845 46 43               dui.cum@hotmail.couk
# 4     Uriel Romero     07381 542211             elit.nulla@outlook.com
# ..             ...              ...                                ...
# 95   Hermione Carr      0800 272602         non.dapibus@protonmail.com
# 96    Darrel Gates  (024) 0676 6116            orci.phasellus@yahoo.ca
# 97  Marshall Sykes      0800 728475         sapien.cras@protonmail.org
# 98    Hyatt Ashley    0873 882 4844                imperdiet@yahoo.org
# 99   Palmer Bowers    076 9264 4467                      risus@aol.com
#
#                              address    postalZip        region  \
# 0            Ap #556-6076 Lorem, Av.        18838  Azad Kashmir
# 1                893-9946 Sociis Rd.       575444      Victoria
# 2                  9010 Auctor. Road        25252   East Region
# 3                560-9011 Magna. St.       491187        Manisa
# 4                  596-1288 Amet Rd.         6700   Nova Scotia
# ..                               ...          ...           ...
# 95                721-3192 Magna Rd.        26930    Queensland
# 96       P.O. Box 976, 7887 Diam St.         4144    West Papua
# 97                 1495 Egestas. Rd.        18102       Utrecht
# 98  P.O. Box 490, 4963 Mauris Avenue        16882     Trøndelag
# 99              Ap #698-4249 Sed St.  30966-60458         Delta
#
#            country  list                                               text  \
# 0          Ireland     1  pede ac urna. Ut tincidunt vehicula risus. Nul...
# 1            India    19  eget odio. Aliquam vulputate ullamcorper magna...
# 2         Pakistan    17  senectus et netus et malesuada fames ac turpis...
# 3         Pakistan     1  dui augue eu tellus. Phasellus elit pede, male...
# 4        Singapore    11  vestibulum massa rutrum magna. Cras convallis ...
# ..             ...   ...                                                ...
# 95        Pakistan    19  orci, adipiscing non, luctus sit amet, faucibu...
# 96  United Kingdom     1  amet ultricies sem magna nec quam. Curabitur v...
# 97           India     1  mi lacinia mattis. Integer eu lacus. Quisque i...
# 98         Vietnam     7  vestibulum. Mauris magna. Duis dignissim tempo...
# 99          Norway    11  nec orci. Donec nibh. Quisque nonummy ipsum no...
#
#     numberrange currency alphanumeric               name_and_phone
# 0             2    $3.61  NGM77DMT8HR           Carl Todd0800 1111
# 1             1   $40.74  ROO25QJR7EJ   Imani Hartman070 6524 1233
# 2             1   $84.87  OAM72YZF3QW     Lynn Carver0980 367 7825
# 3             2   $36.73  HDQ00BJN2QA      Sade Martinez0845 46 43
# 4             4   $45.69  VTX15TUS7TC     Uriel Romero07381 542211
# ..          ...      ...          ...                          ...
# 95            3    $6.14  UDS39INL1CX     Hermione Carr0800 272602
# 96            7   $79.54  PXO54TUV8NH  Darrel Gates(024) 0676 6116
# 97            7   $25.30  IUC28LDY7MM    Marshall Sykes0800 728475
# 98            2   $36.24  HWP81EEB2HK    Hyatt Ashley0873 882 4844
# 99            8   $89.52  SXH88MTP8RT   Palmer Bowers076 9264 4467
#
# [100 rows x 13 columns]

# %%
# Drop columns with any missing values
df.dropna(axis=1)
# Out:
#               name            phone                              email  \
# 0        Carl Todd        0800 1111  mauris.suspendisse@protonmail.net
# 1    Imani Hartman    070 6524 1233                 tempor@hotmail.edu
# 2      Lynn Carver    0980 367 7825        convallis.erat.eget@aol.org
# 3    Sade Martinez       0845 46 43               dui.cum@hotmail.couk
# 4     Uriel Romero     07381 542211             elit.nulla@outlook.com
# ..             ...              ...                                ...
# 95   Hermione Carr      0800 272602         non.dapibus@protonmail.com
# 96    Darrel Gates  (024) 0676 6116            orci.phasellus@yahoo.ca
# 97  Marshall Sykes      0800 728475         sapien.cras@protonmail.org
# 98    Hyatt Ashley    0873 882 4844                imperdiet@yahoo.org
# 99   Palmer Bowers    076 9264 4467                      risus@aol.com
#
#                              address    postalZip        region  \
# 0            Ap #556-6076 Lorem, Av.        18838  Azad Kashmir
# 1                893-9946 Sociis Rd.       575444      Victoria
# 2                  9010 Auctor. Road        25252   East Region
# 3                560-9011 Magna. St.       491187        Manisa
# 4                  596-1288 Amet Rd.         6700   Nova Scotia
# ..                               ...          ...           ...
# 95                721-3192 Magna Rd.        26930    Queensland
# 96       P.O. Box 976, 7887 Diam St.         4144    West Papua
# 97                 1495 Egestas. Rd.        18102       Utrecht
# 98  P.O. Box 490, 4963 Mauris Avenue        16882     Trøndelag
# 99              Ap #698-4249 Sed St.  30966-60458         Delta
#
#            country  list                                               text  \
# 0          Ireland     1  pede ac urna. Ut tincidunt vehicula risus. Nul...
# 1            India    19  eget odio. Aliquam vulputate ullamcorper magna...
# 2         Pakistan    17  senectus et netus et malesuada fames ac turpis...
# 3         Pakistan     1  dui augue eu tellus. Phasellus elit pede, male...
# 4        Singapore    11  vestibulum massa rutrum magna. Cras convallis ...
# ..             ...   ...                                                ...
# 95        Pakistan    19  orci, adipiscing non, luctus sit amet, faucibu...
# 96  United Kingdom     1  amet ultricies sem magna nec quam. Curabitur v...
# 97           India     1  mi lacinia mattis. Integer eu lacus. Quisque i...
# 98         Vietnam     7  vestibulum. Mauris magna. Duis dignissim tempo...
# 99          Norway    11  nec orci. Donec nibh. Quisque nonummy ipsum no...
#
#     numberrange currency alphanumeric               name_and_phone
# 0             2    $3.61  NGM77DMT8HR           Carl Todd0800 1111
# 1             1   $40.74  ROO25QJR7EJ   Imani Hartman070 6524 1233
# 2             1   $84.87  OAM72YZF3QW     Lynn Carver0980 367 7825
# 3             2   $36.73  HDQ00BJN2QA      Sade Martinez0845 46 43
# 4             4   $45.69  VTX15TUS7TC     Uriel Romero07381 542211
# ..          ...      ...          ...                          ...
# 95            3    $6.14  UDS39INL1CX     Hermione Carr0800 272602
# 96            7   $79.54  PXO54TUV8NH  Darrel Gates(024) 0676 6116
# 97            7   $25.30  IUC28LDY7MM    Marshall Sykes0800 728475
# 98            2   $36.24  HWP81EEB2HK    Hyatt Ashley0873 882 4844
# 99            8   $89.52  SXH88MTP8RT   Palmer Bowers076 9264 4467
#
# [100 rows x 13 columns]

# %% [markdown]
# ### Filling Missing Data
# You can replace missing values with a specific value using `fillna()`.
#
# #### Example:

# %%
# Fill missing values with a specific value
df.fillna(0)
# Out:
#               name            phone                              email  \
# 0        Carl Todd        0800 1111  mauris.suspendisse@protonmail.net
# 1    Imani Hartman    070 6524 1233                 tempor@hotmail.edu
# 2      Lynn Carver    0980 367 7825        convallis.erat.eget@aol.org
# 3    Sade Martinez       0845 46 43               dui.cum@hotmail.couk
# 4     Uriel Romero     07381 542211             elit.nulla@outlook.com
# ..             ...              ...                                ...
# 95   Hermione Carr      0800 272602         non.dapibus@protonmail.com
# 96    Darrel Gates  (024) 0676 6116            orci.phasellus@yahoo.ca
# 97  Marshall Sykes      0800 728475         sapien.cras@protonmail.org
# 98    Hyatt Ashley    0873 882 4844                imperdiet@yahoo.org
# 99   Palmer Bowers    076 9264 4467                      risus@aol.com
#
#                              address    postalZip        region  \
# 0            Ap #556-6076 Lorem, Av.        18838  Azad Kashmir
# 1                893-9946 Sociis Rd.       575444      Victoria
# 2                  9010 Auctor. Road        25252   East Region
# 3                560-9011 Magna. St.       491187        Manisa
# 4                  596-1288 Amet Rd.         6700   Nova Scotia
# ..                               ...          ...           ...
# 95                721-3192 Magna Rd.        26930    Queensland
# 96       P.O. Box 976, 7887 Diam St.         4144    West Papua
# 97                 1495 Egestas. Rd.        18102       Utrecht
# 98  P.O. Box 490, 4963 Mauris Avenue        16882     Trøndelag
# 99              Ap #698-4249 Sed St.  30966-60458         Delta
#
#            country  list                                               text  \
# 0          Ireland     1  pede ac urna. Ut tincidunt vehicula risus. Nul...
# 1            India    19  eget odio. Aliquam vulputate ullamcorper magna...
# 2         Pakistan    17  senectus et netus et malesuada fames ac turpis...
# 3         Pakistan     1  dui augue eu tellus. Phasellus elit pede, male...
# 4        Singapore    11  vestibulum massa rutrum magna. Cras convallis ...
# ..             ...   ...                                                ...
# 95        Pakistan    19  orci, adipiscing non, luctus sit amet, faucibu...
# 96  United Kingdom     1  amet ultricies sem magna nec quam. Curabitur v...
# 97           India     1  mi lacinia mattis. Integer eu lacus. Quisque i...
# 98         Vietnam     7  vestibulum. Mauris magna. Duis dignissim tempo...
# 99          Norway    11  nec orci. Donec nibh. Quisque nonummy ipsum no...
#
#     numberrange currency alphanumeric               name_and_phone
# 0             2    $3.61  NGM77DMT8HR           Carl Todd0800 1111
# 1             1   $40.74  ROO25QJR7EJ   Imani Hartman070 6524 1233
# 2             1   $84.87  OAM72YZF3QW     Lynn Carver0980 367 7825
# 3             2   $36.73  HDQ00BJN2QA      Sade Martinez0845 46 43
# 4             4   $45.69  VTX15TUS7TC     Uriel Romero07381 542211
# ..          ...      ...          ...                          ...
# 95            3    $6.14  UDS39INL1CX     Hermione Carr0800 272602
# 96            7   $79.54  PXO54TUV8NH  Darrel Gates(024) 0676 6116
# 97            7   $25.30  IUC28LDY7MM    Marshall Sykes0800 728475
# 98            2   $36.24  HWP81EEB2HK    Hyatt Ashley0873 882 4844
# 99            8   $89.52  SXH88MTP8RT   Palmer Bowers076 9264 4467
#
# [100 rows x 13 columns]

# %%
# Fill missing values with the mean of the column
df['phone'].fillna(df['numberrange'].mean())
# Out:
# 0           0800 1111
# 1       070 6524 1233
# 2       0980 367 7825
# 3          0845 46 43
# 4        07381 542211
#            ...
# 95        0800 272602
# 96    (024) 0676 6116
# 97        0800 728475
# 98      0873 882 4844
# 99      076 9264 4467
# Name: phone, Length: 100, dtype: object
